# %% [markdown]
# This page has moved. You can find the file at [Ecommerce-Analytics].(https://github.com/Jbhnd/Ecommerce-Analytics-Data-Warehouse-Analysis-Dashboard/blob/main/notebooks/Ecommerce_Analytics.ipynb)
